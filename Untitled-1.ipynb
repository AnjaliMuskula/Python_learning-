# %% [markdown]
# # Python variable and data types

# %%
### Data types--> (int, float, str, bool) , Input/output
# Variable , Type conversion , f-string , Live sandbox

# %%
age = 12
score = -10
## whole numbers , no decimal , can be negative

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
## float
## numbers with decimals , use scientific notation 
pi = 3.14
temp = -2.5

# %%
print(type(pi))
# Out:
# <class 'float'>

# %%
## str
## Text wrapped in single , double or triple quatoes 
name = 'anjali'
msg = """msg"""

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
# bool
## only two values :- True or false 
is_adult = True

# %%
print(type(is_adult))
# Out:
# <class 'bool'>

# %%
## None type
## meanse 'no value' or 'empty' like null in other languages , very common as a default
result = None

# %%
print(type(result))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # Variable

# %%
## variable acts as a container to store data types or values
# Ex:- a = 10
# here a is variable storing value that is 10

# %% [markdown]
# # Type Conversion

# %%
## Type conversion --> when types need to changes
# the most imp think to know :- user input is always a string .

# %%
# int(x)

int("45")
# Out:
# 45

# %%
a = "34"
convert = int(a)

# %%
print(type(convert))
# Out:
# <class 'int'>

# %%
## f-string --> the modern way to format text
name = 'anjali'
age = 22
print(f'my name is {name}, and age is {age}  ')
# Out:
# my name is anjali, and age is 22

# %% [markdown]
# # input / output

# %%
## output --> print()
#used to display something
# Ex:- print(a)

# %%
## input --> input()
# takes input from user as string by default
# name = input("enter your name")
