# %% [markdown]
# # AI Engineer Roadmap (Beginner → Advanced)
# Editable study notebook
#
# Created: 2026-03-07

# %% [markdown]
# ## How to Use This Notebook
# - You can **edit any section**
# - Add **notes below each topic**
# - Use code cells to **practice Python / ML**
# - Mark topics as **✅ completed**
# - Use weekend sections for **revision notes**

# %% [markdown]
# # Complete AI Roadmap
#
# ## 1. Python & Data Science
# - Python for Data Science
# - NumPy
# - Pandas
# - Data Cleaning
# - Exploratory Data Analysis
# - Matplotlib / Seaborn
#
# ## 2. Mathematics for AI
# - Linear Algebra
# - Probability
# - Statistics
# - Calculus
# - Optimization Techniques
#
# ## 3. Machine Learning
# ### Types
# - Supervised Learning
# - Unsupervised Learning
# - Semi-Supervised Learning
# - Reinforcement Learning
#
# ### Algorithms
# - Linear Regression
# - Logistic Regression
# - Decision Trees
# - Random Forest
# - Support Vector Machines
# - KNN
# - Naive Bayes
# - Gradient Boosting
# - XGBoost
#
# ### Model Evaluation
# - Accuracy
# - Precision
# - Recall
# - F1 Score
# - Confusion Matrix
# - ROC-AUC
# - Cross Validation
#
# ### Feature Engineering
# - Feature Scaling
# - Feature Selection
# - Encoding Techniques
#
# ### Optimization
# - Bias vs Variance
# - Overfitting vs Underfitting
# - Regularization
# - Hyperparameter Tuning
#
# ## 4. Deep Learning
# - Neurons
# - Activation Functions
# - Forward Propagation
# - Backpropagation
# - ANN
# - CNN
# - RNN
# - LSTM
# - GRU
# - Transformers
# - Transfer Learning
#
# ## 5. NLP
# - Text Preprocessing
# - Tokenization
# - Stopwords
# - Stemming
# - Lemmatization
# - Bag of Words
# - TF‑IDF
# - Word2Vec
# - GloVe
# - FastText
# - Attention Mechanism
#
# ## 6. Generative AI
# - GANs
# - VAEs
# - Diffusion Models
# - Large Language Models
# - Prompt Engineering
# - Fine Tuning
# - RAG
# - Vector Databases
# - Embeddings
# - LangChain
# - AI Agents
# - Multimodal AI
#
# ## 7. MLOps
# - Model Deployment
# - Model Monitoring
# - CI/CD
# - Data Versioning
#
# ## 8. AI Applications
# - Computer Vision
# - Speech Recognition
# - Recommendation Systems
# - Chatbots
# - Autonomous Systems

# %% [markdown]
# # 16 Week Study Plan
# Study one topic per day. Weekend = revision + notes.

# %% [markdown]
# ## Week 1
# - **Monday**: Python for Data Science
# - **Tuesday**: NumPy Basics
# - **Wednesday**: NumPy Operations
# - **Thursday**: Pandas Basics
# - **Friday**: Pandas Data Manipulation
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 2
# - **Monday**: Data Cleaning
# - **Tuesday**: Handling Missing Data
# - **Wednesday**: EDA
# - **Thursday**: Data Visualization
# - **Friday**: Feature Understanding
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 3
# - **Monday**: Vectors
# - **Tuesday**: Matrix Operations
# - **Wednesday**: Probability Basics
# - **Thursday**: Statistics Basics
# - **Friday**: Derivatives
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 4
# - **Monday**: Gradient Descent
# - **Tuesday**: Loss Functions
# - **Wednesday**: Optimization Methods
# - **Thursday**: Regularization
# - **Friday**: Bias vs Variance
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 5
# - **Monday**: Intro to Machine Learning
# - **Tuesday**: Types of ML
# - **Wednesday**: Supervised Learning
# - **Thursday**: Unsupervised Learning
# - **Friday**: Reinforcement Learning
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 6
# - **Monday**: Linear Regression
# - **Tuesday**: Logistic Regression
# - **Wednesday**: Decision Trees
# - **Thursday**: Random Forest
# - **Friday**: Support Vector Machine
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 7
# - **Monday**: KNN
# - **Tuesday**: Naive Bayes
# - **Wednesday**: Gradient Boosting
# - **Thursday**: XGBoost
# - **Friday**: Ensemble Learning
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 8
# - **Monday**: Accuracy
# - **Tuesday**: Precision & Recall
# - **Wednesday**: F1 Score
# - **Thursday**: Confusion Matrix
# - **Friday**: ROC-AUC
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 9
# - **Monday**: Neurons
# - **Tuesday**: Activation Functions
# - **Wednesday**: Forward Propagation
# - **Thursday**: Backpropagation
# - **Friday**: Loss Functions
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 10
# - **Monday**: PyTorch Basics
# - **Tuesday**: PyTorch Tensors
# - **Wednesday**: Training Loop
# - **Thursday**: TensorFlow Basics
# - **Friday**: Model Building
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 11
# - **Monday**: CNN Basics
# - **Tuesday**: Convolution Layer
# - **Wednesday**: Pooling Layer
# - **Thursday**: Flattening
# - **Friday**: Image Classification
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 12
# - **Monday**: RNN Basics
# - **Tuesday**: LSTM
# - **Wednesday**: GRU
# - **Thursday**: Transformers
# - **Friday**: Self Attention
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 13
# - **Monday**: Text Preprocessing
# - **Tuesday**: Tokenization
# - **Wednesday**: Stemming
# - **Thursday**: Lemmatization
# - **Friday**: Stopwords
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 14
# - **Monday**: Bag of Words
# - **Tuesday**: TF-IDF
# - **Wednesday**: Word2Vec
# - **Thursday**: GloVe
# - **Friday**: FastText
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 15
# - **Monday**: Intro to Generative AI
# - **Tuesday**: GANs
# - **Wednesday**: VAEs
# - **Thursday**: Diffusion Models
# - **Friday**: LLM Basics
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# ## Week 16
# - **Monday**: Prompt Engineering
# - **Tuesday**: LangChain
# - **Wednesday**: RAG
# - **Thursday**: Vector Databases
# - **Friday**: AI Agents
# - **Saturday**: Revision
# - **Sunday**: Practice / Mini Project

# %%
# Write your notes or practice code here

# %% [markdown]
# # Final AI Projects
#
# Build at least 3 projects:
#
# 1. NLP Sentiment Analysis
# 2. Image Classification (CNN)
# 3. RAG AI Chatbot
# 4. Recommendation System
# 5. ML Prediction System
#
# Use this section to plan your projects.
