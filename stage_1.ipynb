# %% [markdown]
# # Stage 1 — Python Foundations
#
# Topics:
#
# - Python installation & environment
# - Variables and data types
# - Input / Output
# - Operators
# - Conditional statements
# - Loops
# - Functions
# - Lists
# - Tuples
# - Sets
# - Dictionaries
# - String manipulation
# - List comprehensions
# - Lambda functions
# - Error handling
# - Modules and packages

# %%
## Python installation & envirnoment 

# why does it matter?
#--> think of python like a game , you play , you need game 
engine installed , so python is the engine 

# understand what is pip
-->  python's package manager. like an app store for python
libraries
pip install requests
pip list

# virtual envirnoment
--> the problem without venv :-- imagine you have project A that needs 
django version 3 and project B that need django version 4 , if you install both
globally , they fight each other and break 

The solution -- virtual envirnoment :Each project gets its own isolated box
with its own packages , what happens inside one box doesn't affect the other

# step -1 --> create the virtual envirnoment
python -m venv myenv

# step 2 - activate it  (linux)
source myenv/bin/activate

# (window)
myenv\Scripts\activate

# %% [markdown]
# ### variable and data type

# %%
# why does it matter
# 1) what is variable --> variable acts as a container to store data type or values
A variable is a reference to memory 

EX :- x = 10
Internally:-
10 stored in Ram
x points to that memory 

# 2) Data types --> data types tells python which kind of thing we are storing
because python treats a number , a word , a yes/no answer completely different

# %%
#data types
1) int --whole numbers

age = 25
year = 2026

2) float --> decimal number

temp = 3.4
pi = 3.14

3) str --> text(string)
name = 'Arjun'

4) bool --> true or false
is_logged_in = true

5) None Type --> the absence of a value
result = None # means "nothing yet' or 'no value'

# %%
## assing multiple value 
x , y , z = 1,2,3

# %%
print(x)
# Out:
# 1

# %% [markdown]
# # output / input

# %% [markdown]
# A program that can't talk to the outside world is useless ,
#
# Input - getting data in (from keyword , files , APIs)
# Output - sending data out (screen , files , other system)
#
# These are the lungs of your program , every real program breathes through I/O

# %%
#output --> means whatever , print is that is clear_output
a = 10
print(a)
# Out:
# 10

# %%
#input --> here user will send the input or data
#here you have to remember this input will always be in string , bydeault if you want
# differet datatype then you have mention the data type before input

name = input('what is your name')
age = int(input('enter your age'))

# %%
print(name)
print(age)
# Out:
# anjali
# 22
