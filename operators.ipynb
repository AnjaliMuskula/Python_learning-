# %% [markdown]
# # Operators

# %%
# operators is a symbol that tells python to do something with values 5 + 3

# %%
# arithmetic 
# comparison
# logical
# assignment
# Precedence

# %%
# arithmetic = + , -, *, / - division, // - floor division , % modulus(reminder)
** - power
